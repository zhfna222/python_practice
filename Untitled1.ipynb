# %%
import sys
print sys.maxint
# Out:
# 2147483647

# %%
a = 10 + 20j
print a
# Out:
# (10+20j)

# %%
print complex(1,1)
# Out:
# (1+1j)

# %%
s = 'abcd'
print s[::-1]
# Out:
# dcba

# %%
print 'Hello' + '' + 'Wolrd'
print 'Hello' *  3
print '-' * 60
# Out:
# HelloWolrd
# HelloHelloHello
# ------------------------------------------------------------

# %%
d = { 'one' : 'hana', 'two' : 'dul', 'three' : 'set'}
print len(d)
# Out:
# 3

# %%
o = d.items()

# %%
print len(o)
# Out:
# 3

# %%
print type(o)
print type(o[0])
print o[0][0]
print o[0][1]
# Out:
# <type 'list'>
# <type 'tuple'>
# three
# set

# %%
x = [1]
y = [1] 
print id(x)
print id(y)
# Out:
# 63081800
# 63080648

# %%
x = -1
y = -1
print id(x), id(y)
# Out:
# 34309032 34309032

# %%
import sys
a1 = 191919

# %%
sys.getrefcount(a1)
# Out:
# 2

# %%
n = -2
if n > 0:
    print "a"
elif n < 0:
    print "b"
else:
    print "c"
# Out:
# b

# %%
for x in range(2,20):
    for y in range(1,10):
        print x, "*", y, "=", x*y
# Out:
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 3 * 1 = 3
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 4 * 1 = 4
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 7 * 1 = 7
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 8 * 1 = 8
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72
# 9 * 1 = 9
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# 9 * 7 = 63
# 9 * 8 = 72
# 9 * 9 = 81
# 10 * 1 = 10
# 10 * 2 = 20
# 10 * 3 = 30
# 10 * 4 = 40
# 10 * 5 = 50
# ...

# %%
a = input()
a = str(a)
print a[::-1]
# Out:
# 1234
# 4321

# %%
print 5.0 / 5
# Out:
# 1.0

# %%
a = 1, 2
print a
# Out:
# (1, 2)

# %%
import turtle

t = turtle.Turtle()
t.pensize(3)             # 펜 사이즈를 3으로 설정한다.
t.penup()                # 펜을 종이로 부터 들어올린다.
t.goto(-200, -50)        # 해당 좌표로 이동한다.
t.pendown()              # 펜을 종이에 놓는다.
t.circle(40, steps=3)    # 반지름이 40인 원을 3 step으로만 그린다. ==> 삼각형이 그려짐

t.penup()
t.goto(-100, -50)
t.pendown()
t.circle(40, steps=4)

t.penup()
t.goto(0, -50)
t.pendown()
t.circle(40, steps=5)

t.penup()
t.goto(100, -50)
t.pendown()
t.circle(40, steps=6)

t.penup()
t.goto(200, -50)
t.pendown()
t.circle(40, steps=40)

# %%
# This is a guess the number game.
import random

guessesTaken = 0

print('Hello! What is your name?')
myName = raw_input()

number = random.randint(1, 20) # return random integer in range [a, b], including both end points.
print('Well, ' + myName + ', I am thinking of a number between 1 and 20.')

while guessesTaken < 6:
    print('Take a guess.') 
    guess = int(input())

    guessesTaken = guessesTaken + 1

    if guess < number:
        print('Your guess is too low.')

    if guess > number:
        print('Your guess is too high.')

    if guess == number:
        break

if guess == number:
    guessesTaken = str(guessesTaken)
    print('Good job, ' + myName + '! You guessed my number in ' + guessesTaken + ' guesses!')

if guess != number:
    number = str(number)
    print('Nope. The number I was thinking of was ' + number)
# Out:
# Hello! What is your name?
# lee
# Well, lee, I am thinking of a number between 1 and 20.
# Take a guess.
# 10
# Your guess is too high.
# Take a guess.
# 15
# Your guess is too high.
# Take a guess.
# 16
# Your guess is too high.
# Take a guess.
# 17
# Your guess is too high.
# Take a guess.
# 18
# Your guess is too high.
# Take a guess.
# 19
# Your guess is too high.
# Nope. The number I was thinking of was 2

# %%
result = 0
for x in range(100, 1000):
    for y in range(100, 1000):
        t = str(x * y)
        if t[0:3] == t[:2:-1]:
            if (x * y) > result:
                result = x * y
print result
# Out:
# 906609

# %%
def list_input(l):
    l =  l.split()
    for x in range(len(l)):
        l[x] = int(l[x])
    return l

list1 = raw_input()
list1 = list_input(list1)
print list1
# Out:
# 1 2 3 4 56 7
# [1, 2, 3, 4, 56, 7]

# %%
str = raw_input()
l = str.split()
for x in range(len(l)):
    l[x] = int(l[x])

print l
print type(l[0])
# Out:
# 10 20 30 40 50
# [10, 20, 30, 40, 50]
# <type 'int'>

# %% [markdown]
# 프로젝트 오일러 7번

# %%
i = 5
j = True
prime = [2, 3]
while len(prime) < 10001: 
    for x in prime:
        if i % x == 0:
            j = False
            break
    if (j == True):
        prime.append(i)
    else:
        j = True
    i += 1

print prime[-1]
# Out:
# 104743

# %% [markdown]
# 프로젝트 오일러 8번

# %%
f = "..."

max = 0
result = 1
for x in range(0, len(f)-4):
    for y in range(x, x + 5):
        result *= int(f[y])
        if result > max:
            max = result
    result = 1

print max
# Out:
# 40824

# %% [markdown]
# 프로젝트 오일러 9

# %%
for x in range(1, 500):
    for y in range(x, 500):
        for z in range(y, 500):
            if x**2 + y**2 == z**2 and x + y + z == 1000:
                print x * y * z
# Out:
# 31875000

# %% [markdown]
# 프로젝트 오일러 10

# %%
i = 2
result = 0
while i < 2000001:
    if i == 2:
        result += i
    else : 
        for x in range(2, i):
            if i % x == 0 :
                break
            if i - 1 == x:
                result += i
    i += 1

print result

# %%
def rwh_primes1(n):
    sieve = [True] * (n/2)
    for i in xrange(3,int(n**0.5)+1,2):
        if sieve[i/2]:
            sieve[i*i/2::i] = [False] * ((n-i*i-1)/(2*i)+1)
    return [2] + [2*i+1 for i in xrange(1,n/2) if sieve[i]]

print sum(rwh_primes1(2000000))
# Out:
# 142913828922

# %%
p = range(1, 2000001)

# %%
T = (1,2,3,4,1)
T.count(1)
# Out:
# 2

# %%
import random
import time

NUMBER_OF_ELEMENTS = 10000

lst = list(range(NUMBER_OF_ELEMENTS))
random.shuffle(lst)

s = set(lst)

# 해당 원소가 집합/리스트에 포함되어 있는지 검사
startTime = time.time()
for i in range(NUMBER_OF_ELEMENTS):
    i in s
endTime = time.time()
runTime = int((endTime - startTime) * 1000)
print runTime, "ms"

startTime = time.time()
for i in range(NUMBER_OF_ELEMENTS):
    i in lst
endTime = time.time()
runTime = int((endTime - startTime) * 1000)
print runTime, "ms"

# 해당 원소를 집합/리스트로 부터 제거
startTime = time.time()
for i in range(NUMBER_OF_ELEMENTS):
    s.remove(i)
endTime = time.time()
runTime = int((endTime - startTime) * 1000)
print runTime, "ms"

startTime = time.time()
for i in range(NUMBER_OF_ELEMENTS):
    lst.remove(i)
endTime = time.time()
runTime = int((endTime - startTime) * 1000)
print runTime, "ms"
# Out:
# 1 ms
# 900 ms
# 2 ms
# 375 ms

# %%
L1 = [1, 2, 3]

L2 = [4, 5, 6]

d = {'low':L1, 'high':L2}

e = d

f = d.copy()

print d

print e

print f

print

d['low'] = [10, 20, 30]

d['high'][1] = 500

print d

print e

print f

print L2
# Out:
# {'high': [4, 5, 6], 'low': [1, 2, 3]}
# {'high': [4, 5, 6], 'low': [1, 2, 3]}
# {'high': [4, 5, 6], 'low': [1, 2, 3]}
#
# {'high': [4, 500, 6], 'low': [10, 20, 30]}
# {'high': [4, 500, 6], 'low': [10, 20, 30]}
# {'high': [4, 500, 6], 'low': [1, 2, 3]}
# [4, 500, 6]

# %%
L = [1,2,3,4,5]
L[1:3] = [100]
print L[1]
# Out:
# 100

# %%
L = [1,2,3,4,5]
L[1:3] = [(100, 101, 102)]
print L[2]
# Out:
# 4

# %%
a = [1, 2, 3] 

b = a * 3

c = [a] * 3

print b 

print c

a[0] = 0

print b 

print c

print a

print id(b)

print id(a)

print id(c)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]
# [0, 2, 3]
# 61645064
# 63458504
# 63200840

# %%
import string
print len(string.punctuation)
print (string.punctuation)
# Out:
# 32
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
import string
punc = []
for x in range(0, len(string.punctuation)):
    punc.append(string.punctuation[x])

print len(punc)
print type(string.punctuation)
# Out:
# 32
# <type 'str'>

# %%
def cmp_val(a1, a2):
    return cmp(a1[1], a2[1])

d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}
keys = d.keys()
values = d.values()
result = []

for x in range(0, len(keys)):
    t = keys[x], values[x]
    result.append(t)
    
print result

result.sort()
print result

result.sort(reverse = True)
print result

result.sort(cmp_val)
print result

result.sort(cmp_val, reverse = True)
print result
# Out:
# [('four', 4), ('three', 3), ('five', 5), ('two', 2), ('one', 1)]
# [('five', 5), ('four', 4), ('one', 1), ('three', 3), ('two', 2)]
# [('two', 2), ('three', 3), ('one', 1), ('four', 4), ('five', 5)]
# [('one', 1), ('two', 2), ('three', 3), ('four', 4), ('five', 5)]
# [('five', 5), ('four', 4), ('three', 3), ('two', 2), ('one', 1)]

# %%
# -*- coding: utf-8 -*-
import urllib2
import string

def delete_tag_1(char):
    for i in range(0, char.count('<!--')):
        if char.find("<!--") != -1:
            char = char.replace(char[char.find("<!--"):char.find("-->")+3:],"")
    

def delete_tag_2(char):
    for i in range(0, char.count("<")):
        if char.find("<") != -1:
            char = char.replace(char[source.find("<"):char.find(">")+1:],"")
    

def delete_punc(char):
    for x in range(0, len(string.punctuation)):
        char = char.replace(string.punctuation[x], "")
    

source = urllib2.urlopen("http://www.naver.com/").read()

source = delete_tag_1(source)

source = delete_tag_2(source)

source = delete_punc(source)

words = source.split()
words_dic = {}

for word in words:
    print word
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-70542c1a7bb2> in <module>()
#      24 source = delete_tag_1(source)
#      25
# ---> 26 source = delete_tag_2(source)
#      27
#      28 source = delete_punc(source)
#
# <ipython-input-5-70542c1a7bb2> in delete_tag_2(char)
#      10
#      11 def delete_tag_2(char):
# ---> 12     for i in range(0, char.count("<")):
#      13         if char.find("<") != -1:
#      14             char = char.replace(char[source.find("<"):char.find(">")+1:],"")
#
# AttributeError: 'NoneType' object has no attribute 'count'

# %%
list = [1,2,3,4]
sum(list)
# Out:
# 10

# %%
# -*- coding: utf-8 -*-
import urllib2
import string

source = urllib2.urlopen("http://www.naver.com/").read()


for i in range(0, source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")

for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")
        
for punc in string.punctuation: 
    source = source.replace(punc, "")
    
words = source.split()
words_dic = {}

for word in words:
    print word
# Out:
# NAVER
# var
# isLogin
# false
# var
# global
# isSupportedFlicking
# false
# isIPAD
# false
# var
# strHost
# wwwnavercom
# var
# isMobile
# false
# var
# isMyCast
# false
# var
# svr
# var
# LogErrorfunctionbvar
# anew
# Imageasrchttpcecsnavercommbudocumentlocationl1115DLScriptquSXInew
# ArrayquSnew
# Arrayretry0isLoadfunctionaforvar
# bthisquSlength1
# b0bifthisquSbareturn
# truereturn
# falserunOnloadfunctionbdcifdreturnvar
# abreadyStateiftypeof
# aundefinedbonloadDonebonloadDonetruecsetTimeoutd100bonloadd
# returnifloadedacompleteabonloadDonebonloadDonetruesetTimeoutd100elseifthisretry10thisretrysetTimeoutfunctionDLScriptrunOnloadbdc10createJSDomfunctioncbvar
# adocumentcreateElementscript
# ifbsrcasrccelseatextcreturn
# aappendJSDomfunctionadocumentgetElementsByTagNamehead0appendChildaloadDSfunctionbdcifthisisLoadbthisquSthisquSlengthbvar
# athiscreateJSDombsrc
# thisrunOnloadadcthisappendJSDomaelseifdsetTimeoutd100loadXIfunctioncigdifthisisLoadcthisquSDLScriptquSlengthcvar
# ...

# %%
a = [1, 2, 3] 

b = a * 3

c = [a] * 3

print b 

print c

print id(a)
print id(b)
print id(c)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]
# 60949896
# 60949768
# 60950152

# %%
a[0] = 0

print b 

print c
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %%
print id(a)
print id(b)
print id(c)
# Out:
# 60851144
# 60852168
# 55010504
