# %% [markdown]
# ##Assignment3.

# %% [markdown]
# L=[1, 2, 3, 4, 5]일 때 다음 각 문장을 수행한 후의 결과를 보고 납득할 만한 이유를 설명하시오.

# %% [markdown]
# 1) L[1:3] = [100]

# %%
L = [1,2,3,4,5]
L[1:3] = [100]
print L
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# L[1:3] 의 경우 슬라이싱 연산으로 서로 다른 크기에 대한 슬라이싱 치환이 되므로 [2,3]이 [100]으로 교체된다.

# %% [markdown]
# 2) L[1:3] = [(100)]

# %%
L = [1,2,3,4,5]
L[1:3] = [(100)]
print L
# Out:
# [1, 100, 4, 5]

# %% [markdown]
# 1) 과 마찬가지의 이유로 [2,3] 이 [(100)] 으로 교체 되는데 (100) 이나 100이나 같기 때문에 1)과 같은 결과가 나오게 된다.

# %% [markdown]
# 3) L[1:3] = 100

# %%
L = [1,2,3,4,5]
L[1:3] = 100
print L
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-2190a12ebf8f> in <module>()
#       1 L = [1,2,3,4,5]
# ----> 2 L[1:3] = 100
#       3 print L
#
# TypeError: can only assign an iterable

# %% [markdown]
# 리스트를 다른 리스트로 교체할 경우 ' = ' 연산에서는 좌우의 자료형이 같아야 하는데 100은 단순 정수 자료형이므로 시퀀스 자료형인 리스트와 다르므로 에러가 발생하게 됩니다.

# %% [markdown]
# 4) L[1:3] = (100)

# %%
L = [1,2,3,4,5]
L[1:3] = (100)
print L
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-c5aa4b5b4c59> in <module>()
#       1 L = [1,2,3,4,5]
# ----> 2 L[1:3] = (100)
#       3 print L
#
# TypeError: can only assign an iterable

# %% [markdown]
# ()으로 묶어도 튜플 자료형도 아닌 그저 정수형이므로 3)과 같은 이유로 에러가 발생하게 됩니다.

# %% [markdown]
# 5) L[1:3] = (100, 101, 102)

# %%
L = [1,2,3,4,5]
L[1:3] = (100, 101, 102)
print L
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# 리스트에 튜플을 넣는것이 가능하고 1)과 같은 이유로 슬라이싱 치환이 되어 튜플의 원소값들이 차례로 들어가게 된다.

# %% [markdown]
# 6) L[1:3] = [100, 101, 102]

# %%
L = [1,2,3,4,5]
L[1:3] = [100, 101, 102]
print L
# Out:
# [1, 100, 101, 102, 4, 5]

# %% [markdown]
# 1)과 마찬가지로 리스트의 슬라이싱 치환이 이루어져 [100, 101, 102]의 원소값이 차례로 들어가게 된다.

# %% [markdown]
# 7) L[1:3] = [(100, 101, 102)]

# %%
L = [1,2,3,4,5]
L[1:3] = [(100, 101, 102)]
print L
# Out:
# [1, (100, 101, 102), 4, 5]

# %% [markdown]
# [(100, 101, 102)] 안이 튜플로 구성되어 있으므로 튜플은 변경불가의 특성을 지니고 있기때문에 튜플 객체 그대로 슬라이싱 치환이 되어 리스트에 들어가게 된다.

# %% [markdown]
# 8) L[1:3] = [[100, 101, 102]]

# %%
L = [1,2,3,4,5]
L[1:3] = [[100, 101, 102]]
print L
# Out:
# [1, [100, 101, 102], 4, 5]

# %% [markdown]
# L[1:3] = [[100, 101, 102]] 의 경우 중첩리스트이므로 L[1] 자리에 중첩 리스트가 그대로 들어가게 된다.

# %% [markdown]
# 문자열 S = 'Hello World and Python'에 대해 다음 요구사항에 대한 Python 코드를 제시하시오.

# %% [markdown]
# 1)  단어의 순서가 역순으로 되어진 문자열 ('Python and World Hello')을 만들고

# %% [markdown]
# 2) 1)의 결과 문자열에 대해 메소드 split과 join을 이용하여 공백을 모두 없엔 문자열 'PythonandWorldHello'을 만드시오.

# %%
S = 'Hello World and Python'
result = S.split()
result.reverse()

print ' '.join(result)

print ''.join(result)
# Out:
# Python and World Hello
# PythonandWorldHello

# %% [markdown]
# 다음 코드를 보고 물음에 답하시오.

# %% [markdown]
# a = [1, 2, 3]
#
# b = a * 3
#
# c = [a] * 3
#
# print b
#
# print c

# %% [markdown]
# 1) 위 코드를 수행한 이후 다음 코드를 수행한 후 b와 c의 내용을 확인하시오.
#
# a[0] = 0

# %%
a = [1, 2, 3] 

b = a * 3

c = [a] * 3

print b 

print c
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[1, 2, 3], [1, 2, 3], [1, 2, 3]]

# %%
a[0] = 0

print b 

print c
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [[0, 2, 3], [0, 2, 3], [0, 2, 3]]

# %% [markdown]
# 2) b와 c 객체의 차이는 무엇인가?

# %% [markdown]
# b의 경우는 a를 3번 반복하는 새로운 리스트가 생성이 되고 이것은 a의 레퍼런스와는 전혀 상관이 없는 리스트로 생성이 되어진다. 반면 c의 경우 인자로 a라는 리스트 자체를 넣기 때문에 c 가 리스트의 레퍼런스를 가지면서 동시에 리스트의 원소들이 a의 레퍼런스까지 가지게 되어 a를 참조하여 c라는 리스트의 원소를 구성하게 된다. 따라서 b의 경우 a의 변동에 상관없이 생성된 순간의 a의 값을 반복해서 저장하게 되고 c의 경우는 a라는 리스트 자체를 반복하여 원소로 저장하게 된다, 따라서 c는 a가 변동 될 경우 a의 레퍼런스에 변화가 생겨 그 변화를 반영하게 된다.

# %% [markdown]
# 다음 문자열을 ':'을 기준으로 분리하여 리스트로 만들고 각 문자열의 좌우 공백을 제거하시오 (즉, 문자열 S에서 l을 만들어라)
#
# s = '  first star   :   second star   :    third star  '
#
# l = ['first star', 'second star', 'third star']

# %% [markdown]
# 1) for ~ in 문을 이용한 코드를 작성하시오.
#
# 2) 리스트 내포(list comprehension)를 이용한 코드를 작성하시오.

# %%
s = '  first star   :   second star   :    third star  '
s = s.split(':') # 문자열에서 : 을 기준으로 단어 구별
i = [s[x].strip() for x in range(0, len(s))] #리스트의 원소들의 좌우 공백제거
print i
# Out:
# ['first star', 'second star', 'third star']

# %% [markdown]
# 다음과 같이 0보다 큰 정수 리스트 변수 list를 인자로 받는 함수 addall(list)와 addallodd(list)를 for ~ in 리터널과 리스트 내포 방식으로 각각 제시하시오.

# %% [markdown]
# [참고]: 리스트 내포 방식으로 addall() 및 addallodd()함수를 만들 때엔 리스트 내포에 의해 생성된 리스트 결과에 대해 내장 함수를 사용하는 방식을 고려해보시오 (주의: 리스트 내포 방식의 addall() 및 addallodd() 함수의 몸체는 단 1줄로 작성되어야 한다.)

# %% [markdown]
# 1) addall(list) 함수 (리스트 내의 모든 정수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)

# %% [markdown]
# addall([1])
#
# 1
#
# addall([1, 2, 3, 4, 5, 6, 7, 8, 9])
#
# 45

# %%
def addall(list):
    sum = 0
    for x in list:
        sum += x
    return sum

L = [1,2,3,4,5,6,7,8,9]

print addall(L)
# Out:
# 45

# %%
def addall(list):
    return sum([x for x in list])
    

L = [1,2,3,4,5,6,7,8,9]

print addall(L)
# Out:
# 45

# %% [markdown]
# 2) addallodd(list) 함수 (리스트내의 모든 홀수를 더하는 함수로서 해답으로는 for ~ in 리터럴과 리스트 내포 방식으로 각각 제시하시오.)

# %%
def addallodd(list):
    sum = 0
    for x in list:
        if (x % 2 != 0):
            sum += x
    return sum

L = [1,2,3,4,5,6,7,8,9]

print addallodd(L)
# Out:
# 25

# %%
def addallodd(list):
    return sum([x for x in list if x % 2 ]) #홀수인 경우에만 리스트에 들어가도록 함

L = [1,2,3,4,5,6,7,8,9]

print addallodd(L)
# Out:
# 25

# %% [markdown]
# 다음 코드를 보고 물음에 답하시오.
#
# L1 = [1, 2, 3]
#
# L2 = [4, 5, 6]
#
# d = {'low':L1, 'high':L2}
#
# e = d
#
# f = d.copy()
#
# print d
#
# print e
#
# print f
#
# print
#
# d['low'] = [10, 20, 30]
#
# d['high'][1] = 500
#
# print d
#
# print e
#
# print f

# %% [markdown]
# 1) 위 코드의 수행 결과 d와 e는 항상 같은 결과를 출력한다. 그 이유는 무엇인가?

# %% [markdown]
# d와 e 는 '=' 연산자를 사용하므로 d와 e가 가리키고 있는 주소값이 똑같다 따라서 주소값에 있는 자료형이 변하게 되더라도 주소값은 안바뀌므로 똑같은 주소값에 있는 자료형을 출력하게 된다.

# %% [markdown]
# 2) 위 코드의 수행 결과 마지막 f의 내용은 다음과 같다. 이 때 'high' 키의 값 내용 중 500이 출력된 이유와 'low' 키의 값 내용 중 [1, 2, 3]이 출력된 이유를 설명하시오 ([hint]: shallow copy 관점에서 설명하시오.)
#
# {'high': [4, 500, 6], 'low': [1, 2, 3]}

# %% [markdown]
# copy 모듈의 경우 shallow copy 를 하게 되어 객체와 객체가 포함하는 모든 참조는 복사를 하지만 내장된 객체 자체는 복사를 하지 않는다. 따라서 f 는 계속해서 low의 값으로 L1 의 주소값을 가지게 되고 d['low'] = [10,20,30] 에서 L1을 바꾸는것이 아니기 때문에 f에서 low의 값은 바뀌지 않는다. 하지만 d['high'][1] = 500 의 경우 L2의 1번 인덱스의 값이 500으로 바뀌게 된다. 따라서 L1의 원본이 변하였기때문에 f에서 high 의 참조도 같이 바뀌게 되어 high의 값이 바뀌어 출력된다.

# %% [markdown]
# 사전 d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}가 주어졌을 때 다음 요구사항에 맞는 코드를 제시하시오
#
# [참고]: d.keys(), d.values()를 통해 리스트를 얻어낸 후 리스트가 지니고 있는 sort(cmp=None, key=None, reverse=False)함수를 활용하시오.
#
# 1) 키의 알파벳 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#
# 2) 키의 알파벳 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#
# 3) 값의 오름차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.
#
# 4) 값의 내림차순 순서대로 튜플 (키, 값)을 차례대로 출력하시오.

# %%
def cmp_val(a1, a2): #튜플의 원소중 인덱스가 1인 값을 비교하기 위한 함수
    return cmp(a1[1], a2[1])

d = {'one':1, 'two':2, 'three':3, 'four':4, 'five':5}
keys = d.keys()
values = d.values()
result = []

for x in range(0, len(keys)):
    t = keys[x], values[x] #튜플 변환
    result.append(t) #리스트에 튜플 추가
    
print result # 키와 값의 튜플로 구성된 리스트

result.sort() #키의 알파벳 순서 오름정렬
print result

result.sort(reverse = True) #키의 알파벳 순서 내림차순 정렬
print result

result.sort(cmp_val) #값의 오름차순 정렬, 위의 cmp_val함수를 사용
print result

result.sort(cmp_val, reverse = True) #값의 내림차순 정렬
print result
# Out:
# [('four', 4), ('three', 3), ('five', 5), ('two', 2), ('one', 1)]
# [('five', 5), ('four', 4), ('one', 1), ('three', 3), ('two', 2)]
# [('two', 2), ('three', 3), ('one', 1), ('four', 4), ('five', 5)]
# [('one', 1), ('two', 2), ('three', 3), ('four', 4), ('five', 5)]
# [('five', 5), ('four', 4), ('three', 3), ('two', 2), ('one', 1)]

# %% [markdown]
# [프로젝트 오일러 문제 7]

# %%
i = 5 # 시작하는 수 
j = True #소수임을 판단하기 위한 인자
prime = [2, 3] #소수들을 담을 리스트 2, 3은 미리 입력
while len(prime) < 10001: #소수가 10001개가 될때 까지 반복
    for x in prime:
        if i % x == 0: # 판별하려는 수가 소수로 1번이라도 나누어 질 경우
            j = False # False 로 표기 하고 루프를 빠져나간다
            break
    if (j == True): #위의 for문을 빠져나와 소수로 판별 될 경우 
        prime.append(i) # 소수들의 리스트에 추가 
    else:
        j = True #판별 인자를 True로 초기화 
    i += 1 

print prime[-1] #리스트의 가장 마지막 원소 출력
# Out:
# 104743

# %% [markdown]
# [프로젝트 오일러 문제 8]

# %%
f = "..."

max = 0 #최대값을 담을 변수 
result = 1 # 5자리를 곱한 값을 저장할 변수 
for x in range(0, len(f)-4): # 문자열의 처음부터 마지막에서 5개의 문자가 성립될 마지막 인덱스까지의 범위만 돌린다
    for y in range(x, x + 5): # x에서 5개까지의 문자의 인덱스
        result *= int(f[y]) # 처음부터 차례로 곱한 값을 저장
        if result > max: # 결과값이 저장된 최대값보다 큰 경우
            max = result # max 로 결과값을 옮김
    result = 1 # 결과값 초기화

print max
# Out:
# 40824

# %% [markdown]
# [프로젝트 오일러 문제 9]

# %%
for a in range(1, 500): # a의 범위 
    for b in range(a, 500): # a보다 큰 b의 범위 
        for c in range(b, 500): # 피타고라스의 공식을 만족하는 c의 범위 
            if a**2 + b**2 == c**2 and a + b + c == 1000: # 피타고라스의 공식을 만족하면서 총 합이 1000인경우
                print a * b * c # 모두 곱한 값을 출력
# Out:
# 31875000

# %% [markdown]
# Incremental Project] 이전 Assignment 2의 마지막 문제는 웹 URL로 지정된 웹페이지를 문자열로 가져와 모든 HTML 태그 및 CSS와 Javascript를 제외한 순수 텍스트를 얻어내고 그 안에 존재하는 단어를 추출하고 단어들의 총 개수를 출력하는 프로그램을 작성하는 것이었다. 이번에는 그 마지막 숙제를 그대로 확장하여 웹 URL로 지정된 웹페이지 내 순수 텍스트 안에 존재하는 각 단어들에 대해 다음 요구사항 대로 출력하는 프로그램을 작성하시오.

# %% [markdown]
# 요구사항 1. 순수 텍스트 안에 존재하는 단어들에 대해 string 모듈을 활용하여 모든 punctuation (구두문자)를 완벽히 제거하시오.
#
# 예: ['world!', ':', '+hello+', '~python$$$', '=', 'world'] ---> ['world', 'hello', 'python', 'world']
#
# 모든 punctuation을 확인하는 방법은 아래와 같다.
#
# import string
#
# print string.punctuation
#
# 요구사항 2. 만약 punctuation (구두문자)를 제거한 이후 공백으로 판명되는 단어들은 해당 단어 리스트에서 제거하시오.
#
# 예: ['컴퓨터공학부!', '---?', '%지향~', '...'] ---> ['컴퓨터공학부', '지향']
#
# 요구사항 3. 각 단어들의 출현빈도를 사전형태로 저장하여 출력하시오.
#
# 예: ['world', 'hello', 'python', 'world', '컴퓨터공학부', '지향'] ---> {'world': 2,
# 'hello': 1, 'python': 1, '컴퓨터공학부': 1, '지향': 1}
#
# 요구사항 4. 다음 3개의 사이트에 대한 결과를 출력하시오.
#
# http://www.naver.com
#
# http://www.daum.net
#
# http://www.nytimes.com

# %% [markdown]
# http://www.naver.com 의 결과

# %%
# -*- coding: utf-8 -*-
import urllib2
import string

source = urllib2.urlopen("http://www.naver.com/").read()


for i in range(0, source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")

for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")
        
for punc in string.punctuation: # 구두문자를 인자로 반복문 실행
    source = source.replace(punc, "") #source에서 구두문자를 공백으로 바꾼 것을 다시 저장
    
words = source.split() # 공백으로 단어를 나누어 리스트 저장
words_dic = {} # 사전으로 담기 위한 변수

for word in words:
    print word #단어 출력
# Out:
# NAVER
# var
# isLogin
# false
# var
# global
# isSupportedFlicking
# false
# isIPAD
# false
# var
# strHost
# wwwnavercom
# var
# isMobile
# false
# var
# isMyCast
# false
# var
# svr
# var
# LogErrorfunctionbvar
# anew
# Imageasrchttpcecsnavercommbudocumentlocationl1115DLScriptquSXInew
# ArrayquSnew
# Arrayretry0isLoadfunctionaforvar
# bthisquSlength1
# b0bifthisquSbareturn
# truereturn
# falserunOnloadfunctionbdcifdreturnvar
# abreadyStateiftypeof
# aundefinedbonloadDonebonloadDonetruecsetTimeoutd100bonloadd
# returnifloadedacompleteabonloadDonebonloadDonetruesetTimeoutd100elseifthisretry10thisretrysetTimeoutfunctionDLScriptrunOnloadbdc10createJSDomfunctioncbvar
# adocumentcreateElementscript
# ifbsrcasrccelseatextcreturn
# aappendJSDomfunctionadocumentgetElementsByTagNamehead0appendChildaloadDSfunctionbdcifthisisLoadbthisquSthisquSlengthbvar
# athiscreateJSDombsrc
# thisrunOnloadadcthisappendJSDomaelseifdsetTimeoutd100loadXIfunctioncigdifthisisLoadcthisquSDLScriptquSlengthcvar
# ...

# %%
for word in words: #단어들을 인자로 반복문 실행
    if word not in words_dic.keys(): # words_dic 에 키로 저장된 단어가 없을 경우 
        words_dic[word] = words.count(word) # 단어를 키로 단어의 갯수를 값으로 사전에 저장

for key in words_dic.keys(): # 사전 출력
    print key, ':' , words_dic[key]
# Out:
# nameencurl : 1
# classthumb : 12
# classinputtext : 1
# classlytsqwg : 1
# classnewsssort : 1
# targettop : 2
# 39의외의 : 2
# onclickclickcrthissvcdefaultservicemapevent : 1
# classfmenu : 1
# idNS056a : 1
# hrefhttpwwwnavercom : 4
# classtagem월목 : 1
# 해제aa : 1
# 제외 : 1
# classnewsssort2 : 1
# classtsqh투데이h3 : 1
# srchttpimgnavernetstaticnewsstandup20140715109gif : 1
# fieldset : 6
# idsvcmore : 1
# Eshortcutname금융 : 1
# 주요 : 3
# 홈 : 1
# classnextspan : 1
# hrefhttpnv2adnavercomadshowunit002APnrefreshx0httpnv2adnavercomadshowunit002APnrefreshx0aiframe : 1
# 검색어dt : 1
# classprespan : 1
# valuedic사전option : 1
# hrefnewscast2 : 1
# 때는 : 4
# clickcrthistcctvcorigin7803E8010000000295F6 : 1
# idsvcshopping : 1
# classir라이프spanaspan : 1
# hrefhttpweathernavercomrgntownWetrnhnnaverRgnCd13113135 : 1
# 자주 : 1
# classscate : 1
# classtsqwgopen : 1
# 등 : 1
# styledisplaynoneintxtspanliul : 1
# onclickdocumentgetElementByIdthemecasttabIndex : 1
# hrefrulesyouthpolicyhtml : 1
# classnewss : 1
# ...

# %% [markdown]
# http://www.daum.net 의 결과

# %%
source = urllib2.urlopen("http://www.daum.net/").read()


for i in range(0, source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")

for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")
        
for punc in string.punctuation: 
    source = source.replace(punc, "")
    
words = source.split()
words_dic = {}

for word in words:
    print word
# Out:
# Daum
# ndash
# 모으다
# 잇다
# 흔들다
# bodydivdldtddulollih1h2h3h4h5h6precodeformfieldsetlegendtextareapblockquotethtdinputselecttextareabutton
# margin0padding0
# fieldsetimg
# border0
# none
# dlulolmenuli
# liststylenone
# blockquote
# q
# quotes
# none
# blockquotebefore
# blockquoteafterqbefore
# qafter
# contentcontentnone
# inputselecttextareabutton
# verticalalignmiddle
# inputmsclear
# displaynone
# button
# border0
# nonebackgroundcolortransparentcursorpointer
# body
# backgroundfff
# urlhttpi1daumcdnnetdecocomicstopdeco2014v2bgtopbargifv1102
# repeatx
# 0
# 0directionltr
# bodyh1h2h3h4thtdinputselecttextareabutton
# fontsize12pxlineheight15fontfamily돋움dotumsansserifcolor333
# a
# color262626textdecorationnone
# ahover
# color4559e9textdecorationunderline
# aactive
# backgroundcolortransparent
# addresscaptioncitecodedfnemvar
# fontstylenormalfontweightnormal
# headermainasidearticlefooter
# displayblock
# wrapdaum
# width940pxmargin0
# auto
# headdaum
# ...

# %%
for word in words:
    if word not in words_dic.keys():
        words_dic[word] = words.count(word)

for key in words_dic.keys():
    print key, ':' , words_dic[key]
# Out:
# stock : 2
# top7px : 1
# titstory : 11
# 0fontweightboldfontsize11pxlineheight13pxfontfamilytahomasansserifcolor949494 : 1
# 6px : 22
# titissuerank : 3
# suggestBox : 75
# wrapthesong : 1
# promotionimg : 8
# linkprotect : 1
# height143 : 1
# classlistimg : 3
# height103pxmargintop9px : 2
# displayblockheight15pxmarginleft15pxpaddingtop14pxlineheight15px : 1
# icocolon : 1
# classcolorg빵츄em : 1
# top52pxheight22pxlineheight24px : 1
# srchttpt1daumcdnnetthumbC190x105fnamehttpt1daumcdnnetsectionoc79e1515c11f1402b805cde22a32af205 : 1
# classstocktoday : 1
# hrefhttpmediadaumnetv20151020205207554 : 1
# hrefhttptvpotdaumnetmypotViewdoowneridlP3581RpkRs0ampclipid71646914 : 1
# realestateon : 2
# 거치는 : 1
# left15px : 3
# 좋아 : 1
# fieldset : 1
# idmediaPrevBtn : 1
# 재개quot : 1
# 팁 : 3
# border1px : 2
# txtapp : 1
# hrefhttplikedaumnetbestdaily : 1
# 380px : 4
# hrefhttpgoshoppingdaumnetlinkgodaumdataseqAXyED : 1
# 9px : 6
# width188pxheight159pxpadding0 : 1
# bottom8px : 1
# qafter : 1
# ...

# %% [markdown]
# http://www.nytimes.com 의 결과

# %%
source = urllib2.urlopen("http://www.nytimes.com/").read()


for i in range(0, source.count('<!--')):
    if source.find("<!--") != -1:
        source = source.replace(source[source.find("<!--"):source.find("-->")+3:],"")

for i in range(0,source.count("<")):
    if source.find("<") != -1:
        source = source.replace(source[source.find("<"):source.find(">")+1:],"")
        
for punc in string.punctuation: 
    source = source.replace(punc, "")
    
words = source.split()
words_dic = {}

for word in words:
    print word
# Out:
# The
# New
# York
# Times
# Breaking
# News
# World
# News
# Multimedia
# windowNREUMNREUMnrrequirefunctionentfunction
# rtifntvar
# ontexportset0calloexportsfunctionnvar
# oet1nreturn
# roonooexportsreturn
# ntexportsiffunctiontypeof
# nrrequirereturn
# nrrequireforvar
# o0oppupapplystreturn
# sfunction
# aenfececoncatnfunction
# cereturn
# fefunction
# ureturn
# tnvar
# freturnonaemitncreateulistenersceventsffunction
# rreturnvar
# onrcontextiegosnexportstgos7eSDFheefunctionennexportseQJf3ax3functionenfunction
# tereturn
# functionrenew
# DategetTimeconcatiargumentsvar
# rehandleoe1ie2undefinedtypeof
# windownewrelicnewrelicwindowNREUMvar
# asetPageViewNameaddPageActionsetCustomAttributefinishedaddToTraceinlineHitnoticeErroroafunctionenwindowNREUMntapinnexportswindowNREUM112213handleD5DuLPgosfunctionennexportse7eSDFh7eSDFhfunctionenfunction
# tentifrcallenreturn
# envar
# otifObjectdefinePropertyObjectkeystryreturn
# ObjectdefinePropertyenvalueowritable0enumerable1ocatchireturn
# ...

# %%
for word in words:
    if word not in words_dic.keys():
        words_dic[word] = words.count(word)

for key in words_dic.keys():
    print key, ':' , words_dic[key]
# Out:
# hrefhttpwwwnytimescom20151019opinionhowtofighthomelessnesshtml : 1
# classthumb : 35
# Lead : 1
# classcaptiontextA : 1
# idtopnews100000003979730 : 1
# Rout : 1
# 6px : 3
# ‘Jason : 1
# Celebrationsa : 1
# idtopnews100000003985735 : 1
# classinsidenytregion : 1
# 0833 : 1
# adxclientsidead : 1
# offenses : 1
# ThickRimmed : 1
# violate : 1
# hrefhttpwwwnytimescomsectionmagazineMagazine : 1
# Orleansah2 : 1
# Watch : 2
# urlhttpcssnytcomimagesiconsbullet4x4gif : 1
# under : 1
# Deadline : 1
# RehabilitationDrugs : 1
# h4sectionHeaderHome : 2
# Yaphank : 1
# h3containsThe : 1
# League : 1
# regional : 1
# JNew : 1
# envar : 1
# every : 1
# Timesa : 1
# Military : 1
# Moon : 1
# encounter : 1
# nrrequireforvar : 1
# idtopnews100000003665755 : 1
# InBev : 1
# cause : 1
# hrefhttpwwwnytimescompagestheaterindexhtmlTheatera : 1
# fontweight : 12
# hrefhttpwwwnytimescom20151020opinionputinspartitionplanforsyriahtml : 1
# Go : 1
# Accepts : 1
# force : 2
# 0052 : 1
# 0051 : 1
# ...

# %% [markdown]
# 소감 : [Incremental Project] 를 처음에는 어렵게만 느껴지고 실제로도 어려워서 풀지 못했었는데 문자열의 처리와 함수들을 조금 더 익히고 공부하다 보니 지금은 어디에 어떻게 어떤 함수를 써야 할지 알게 됬고 사전의 여러 함수들도 다시 공부 할 수 있어서 좋았습니다. 사전을 그냥 출력할 경우 한글이 깨지는 경우는 교수님이 알려주신대로 유니코드로 인코딩해서 출력을 해봐도 인자들 앞에 u' 만 붙어 깨져 나와서 for문으로 출력을 했습니다. 한글 출력에 대해서도 이것저것 찾아보았지만 어려운 내용도 있어서 조금 더 배워야 할 것 같습니다. 그리고 프로젝트 오일러 문제도 여러가지를 생각할 수 있어서 좋았던것 같습니다. 단순 코딩이 아닌 수학적인 내용들을 알고 접근해서 구현해야 하는게 실력 향상에 도움이 되는것 같습니다.
